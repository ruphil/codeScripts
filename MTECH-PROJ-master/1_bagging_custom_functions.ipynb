# %%
import pickle
import numpy as np
import pandas as pd
from pandas import ExcelWriter
import matplotlib.pyplot as plt
import itertools
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingRegressor

# %%
def function1(a,b,c,d):
    return 2*a+3*b+5*c+7*d

def function2(a,b,c,d):
    return np.sin(a)*np.cos(b)*np.sin(c)*np.cos(d)

def function3(a,b,c,d):
    return a + np.power(b,c)*d

def function4(a,b,c,d):
    return a*b*c*d
    
def data_generator():
    num_data = 10000
    a = np.random.rand(num_data)
    b = np.random.rand(num_data)
    c = np.random.rand(num_data)
    d = np.random.rand(num_data)
    return a,b,c,d

def make_data_ready(data):
    X = np.transpose(data[0:3])
    y = data[4]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
#     X_train, X_test, y_train, y_test = X_train.values, X_test.values, y_train.values, y_test.values
    return X_train, X_test, y_train, y_test

def bagging(X_train, X_test, y_train, y_test):
    clf = BaggingRegressor()
    clf.fit(X_train, y_train)
    score = clf.score(X_test, y_test)
    return clf, score

def plot_y_vs_y_predicted(clf, X_test, y_test):
    y_predict = clf.predict(X_test)
    plt.scatter(y_test, y_predict)
    plt.show()

# %%
def main_func():
    a,b,c,d = data_generator()
    Y = function3(a,b,c,d)
    X_train, X_test, y_train, y_test = make_data_ready([a,b,c,d,Y])
#     print (Y)
#     print (X_train, X_test, y_train, y_test)
    clf, score = bagging(X_train, X_test, y_train, y_test)
    print (score)
    plot_y_vs_y_predicted(clf, X_test, y_test)

# Main Function
main_func()
# Out:
# 0.6022949820527191
